# %%
import pandas as pd
import numpy as np
from io import StringIO

# %% [markdown]
# Imagina que eres un investigador en el mundo de Pokémon y has recibido una base de datos con información desactualizada y desordenada sobre avistamientos de Pokémon. Tu misión es limpiar y actualizar esta base de datos para que pueda ser utilizada en un estudio sobre la población de Pokémon en la región.

# %% [markdown]
# Datos Iniciales
#
# Los datos iniciales contienen las siguientes columnas:
#
#     SightingDate: Fecha del avistamiento.
#     TrainerID: Identificación del entrenador que reportó el avistamiento.
#     PokemonName: Nombre del Pokémon avistado.
#     CP: Puntos de combate del Pokémon reportado.
#     HP: Puntos de salud del Pokémon reportado.
#     Type: Tipo del Pokémon.
#     Weather: Clima durante el avistamiento.

# %% [markdown]
# # 1 Carga de Datos

# %%
pip install chardet
# Out:
# Collecting chardet
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 677.7 kB/s eta 0:00:0000:0100:01
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import chardet

path_datos = 'pokemon.csv'

# Detecta la codificación del archivo CSV
with open(path_datos, 'rb') as f:
    result = chardet.detect(f.read())

print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
path_datos = 'pokemon.csv'

# Intenta leer el archivo CSV con codificación 'utf-8'

df = pd.read_csv(path_datos, encoding='ISO-8859-1')
df
# Ahora, 'df' debería contener tus datos correctamente
# Out:
#                SightingDate    SightingTimeUTC TrainerID PokémonName       CP  \
# 0  2023-11-08T14:00:00+0000  2023-11-08T14:00Z     TR123     Pikachu      500
# 1  2023-07-12T09:30:00+0100  2023-07-12T08:30Z     TR456       Eevee  MISSING
# 2  2023/02/23T22:15:00+0900  2023-02-23T13:15Z     TR789    Magicarp    1,000
# 3  2023-04-30T06:45:00-0400  2023-04-30T10:45Z     TR101      Gengar      800
# 4  2023-08-15T16:00:00+1000                NaN     TR102   Bulbasaur      750
#
#    HP          Type        Weather
# 0  35      Electric          Clear
# 1  55        Normal         Cloudy
# 2  10         Water           Rain
# 3  45         Ghost  PARTLY_CLOUDY
# 4  50  Grass/Poison          Sunny

# %% [markdown]
# # Limpieza de Datos

# %% [markdown]
# ## 1 Normalizacion de Zonas Horarias

# %% [markdown]
# Normaliza la columna `'SightingTimeUTC'` a la zona horaria UTC y convierte `'SightingDate'` al mismo formato de tiempo.

# %%
from dateutil import parser
import pytz

from datetime import datetime

def convert_date_format(date_str):
    try:
        date_obj = datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')
        formatted_date = pytz.utc.localize(date_obj)
    except ValueError:
        try:
            date_obj = parser.parse(date_str)
            formatted_date = date_obj.astimezone(pytz.utc)
        except:
            return date_str
    return formatted_date


df['SightingDate'] = df['SightingDate'].apply(convert_date_format)
df['SightingDate'] = pd.to_datetime(df['SightingDate'], utc=True)
df['SightingTimeUTC'] = pd.to_datetime(df['SightingTimeUTC'], utc=True)



# Display the DataFrame with normalized UTC dates and times
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#         CP  HP          Type        Weather
# 0      500  35      Electric          Clear
# 1  MISSING  55        Normal         Cloudy
# 2    1,000  10         Water           Rain
# 3      800  45         Ghost  PARTLY_CLOUDY
# 4      750  50  Grass/Poison          Sunny

# %%
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#         CP  HP          Type        Weather
# 0      500  35      Electric          Clear
# 1  MISSING  55        Normal         Cloudy
# 2    1,000  10         Water           Rain
# 3      800  45         Ghost  PARTLY_CLOUDY
# 4      750  50  Grass/Poison          Sunny

# %% [markdown]
# Compara si la fecha de la columna `'SightingDate'` coincide con la fecha en `'SightingTimeUTC'` una vez normalizada.

# %%
result = df['SightingDate'].dt.date == df['SightingTimeUTC'].dt.date
result
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# Ajusta `'SightingTimeUTC'` a la zona horaria local de cada entrenador y crea una columna `'SightingTimeLocal'`.

# %%
df['SightingTimeLocal'] = df['SightingDate'].copy()

# %%
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#         CP  HP          Type        Weather         SightingTimeLocal
# 0      500  35      Electric          Clear 2023-11-08 14:00:00+00:00
# 1  MISSING  55        Normal         Cloudy 2023-07-12 08:30:00+00:00
# 2    1,000  10         Water           Rain 2023-02-23 13:15:00+00:00
# 3      800  45         Ghost  PARTLY_CLOUDY 2023-04-30 10:45:00+00:00
# 4      750  50  Grass/Poison          Sunny 2023-08-15 06:00:00+00:00

# %% [markdown]
# Calcula el tiempo transcurrido desde el momento del avistamiento hasta `'ahora'` (tu hora local) y crea una columna `'TimeSinceSighting'`.

# %%
now = pd.Timestamp(datetime.now(), tz='UTC')
df['TimeSinceSighting'] = now - df['SightingDate']

# %%
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#         CP  HP          Type        Weather         SightingTimeLocal  \
# 0      500  35      Electric          Clear 2023-11-08 14:00:00+00:00
# 1  MISSING  55        Normal         Cloudy 2023-07-12 08:30:00+00:00
# 2    1,000  10         Water           Rain 2023-02-23 13:15:00+00:00
# 3      800  45         Ghost  PARTLY_CLOUDY 2023-04-30 10:45:00+00:00
# 4      750  50  Grass/Poison          Sunny 2023-08-15 06:00:00+00:00
#
#          TimeSinceSighting
# 0   5 days 04:48:14.114074
# 1 124 days 10:18:14.114074
# 2 263 days 05:33:14.114074
# 3 197 days 08:03:14.114074
# 4  90 days 12:48:14.114074

# %% [markdown]
# ## 2. Limpeiza de IDs

# %% [markdown]
# Llena los valores faltantes en `'TrainerID'` con el ID `'UNKNOWN'`.

# %%
df['TrainerID'] = df['TrainerID'].fillna('UKNOWN')

# %% [markdown]
# ## 3. Corrección de Nombres de Pokémon

# %% [markdown]
# Asegúrate de que los nombres de Pokémon estén capitalizados correctamente.

# %%
#Itera sobre la columna 'PokemonName' asegurandote que esté en mayúsculas la primera letra de cada palabra:
df['PokémonName'] = df['PokémonName'].apply(lambda x: x.title())
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#         CP  HP          Type        Weather         SightingTimeLocal  \
# 0      500  35      Electric          Clear 2023-11-08 14:00:00+00:00
# 1  MISSING  55        Normal         Cloudy 2023-07-12 08:30:00+00:00
# 2    1,000  10         Water           Rain 2023-02-23 13:15:00+00:00
# 3      800  45         Ghost  PARTLY_CLOUDY 2023-04-30 10:45:00+00:00
# 4      750  50  Grass/Poison          Sunny 2023-08-15 06:00:00+00:00
#
#          TimeSinceSighting
# 0   5 days 04:48:43.904806
# 1 124 days 10:18:43.904806
# 2 263 days 05:33:43.904806
# 3 197 days 08:03:43.904806
# 4  90 days 12:48:43.904806

# %% [markdown]
# ## 4. Conversión de 'CP' y 'HP' a Numéricos

# %% [markdown]
# Convierte `'CP'` y `'HP'` a valores numéricos, manejando los `'MISSING'` y comas como separadores de miles.

# %%
#Convierte el string 'MISSING' a NaN en la columna 'CP','HP':
df['CP'] = df['CP'].replace('MISSING', np.nan)
df['HP'] = df['HP'].replace('MISSING', np.nan)


#Convierte las comas en separadores de miles en la columna 'CP':
df['CP'] = df['CP'].str.replace(',', '')
df['HP'] = df['HP'].str.replace(',', '')

#Convierte en numérico
df['CP'] = pd.to_numeric(df['CP'], errors='coerce')
df['HP'] = pd.to_numeric(df['HP'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/gerardoguerrero/fdd_o23/tareas/214_gaga/debugg/debugging_pokemon.ipynb Cell 29 line 8
#       <a href='vscode-notebook-cell:/Users/gerardoguerrero/fdd_o23/tareas/214_gaga/debugg/debugging_pokemon.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> #Convierte las comas en separadores de miles en la columna 'CP':
#       <a href='vscode-notebook-cell:/Users/gerardoguerrero/fdd_o23/tareas/214_gaga/debugg/debugging_pokemon.ipynb#X34sZmlsZQ%3D%3D?line=6'>7</a> df['CP'] = df['CP'].str.replace(',', '')
# ----> <a href='vscode-notebook-cell:/Users/gerardoguerrero/fdd_o23/tareas/214_gaga/debugg/debugging_pokemon.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a> df['HP'] = df['HP'].str.replace(',', '')
#      <a href='vscode-notebook-cell:/Users/gerardoguerrero/fdd_o23/tareas/214_gaga/debugg/debugging_pokemon.ipynb#X34sZmlsZQ%3D%3D?line=9'>10</a> #Convierte en numérico
#      <a href='vscode-notebook-cell:/Users/gerardoguerrero/fdd_o23/tareas/214_gaga/debugg/debugging_pokemon.ipynb#X34sZmlsZQ%3D%3D?line=10'>11</a> df['CP'] = pd.to_numeric(df['CP'], errors='coerce')
#
# File ~/anaconda3/envs/mi_entorno_pandas/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~/anaconda3/envs/mi_entorno_pandas/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/anaconda3/envs/mi_entorno_pandas/lib/python3.11/site-packages/pandas/core/strings/accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/anaconda3/envs/mi_entorno_pandas/lib/python3.11/site-packages/pandas/core/strings/accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df['CP'] = pd.to_numeric(df['CP'], errors='coerce')
df['HP'] = pd.to_numeric(df['HP'], errors='coerce')

# %% [markdown]
# ## 5. Estandarización de 'Type'

# %% [markdown]
# Divide la columna `'Type'` en `'PrimaryType'` y `'SecondaryType'` cuando hay dos tipos.

# %%
# Suponiendo que 'df' es tu DataFrame
df[['PrimaryType', 'SecondaryType']] = df['Type'].str.split('/', expand=True)

# %%
# Suponiendo que 'df' es tu DataFrame
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#        CP  HP          Type        Weather         SightingTimeLocal  \
# 0   500.0  35      Electric          CLEAR 2023-11-08 14:00:00+00:00
# 1     NaN  55        Normal         CLOUDY 2023-07-12 08:30:00+00:00
# 2  1000.0  10         Water           RAIN 2023-02-23 13:15:00+00:00
# 3   800.0  45         Ghost  PARTLY_CLOUDY 2023-04-30 10:45:00+00:00
# 4   750.0  50  Grass/Poison          SUNNY 2023-08-15 06:00:00+00:00
#
#          TimeSinceSighting PrimaryType SecondaryType
# 0   5 days 04:48:43.904806    Electric          None
# 1 124 days 10:18:43.904806      Normal          None
# 2 263 days 05:33:43.904806       Water          None
# 3 197 days 08:03:43.904806       Ghost          None
# 4  90 days 12:48:43.904806       Grass        Poison

# %% [markdown]
# ## 6. Corrección del Clima

# %% [markdown]
# Estándariza la columna `'Weather'` para que todos los valores sean mayúsculas.

# %%
df['Weather'] = df['Weather'].apply(lambda x: x.upper())

# %%
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#        CP  HP          Type        Weather         SightingTimeLocal  \
# 0   500.0  35      Electric          CLEAR 2023-11-08 14:00:00+00:00
# 1     NaN  55        Normal         CLOUDY 2023-07-12 08:30:00+00:00
# 2  1000.0  10         Water           RAIN 2023-02-23 13:15:00+00:00
# 3   800.0  45         Ghost  PARTLY_CLOUDY 2023-04-30 10:45:00+00:00
# 4   750.0  50  Grass/Poison          SUNNY 2023-08-15 06:00:00+00:00
#
#          TimeSinceSighting PrimaryType SecondaryType
# 0   5 days 04:48:43.904806    Electric          None
# 1 124 days 10:18:43.904806      Normal          None
# 2 263 days 05:33:43.904806       Water          None
# 3 197 days 08:03:43.904806       Ghost          None
# 4  90 days 12:48:43.904806       Grass        Poison

# %% [markdown]
# # 3 Analisis de Datos

# %% [markdown]
# ## Agrupaciones

# %% [markdown]
# Agrupa el DataFrame por `'Type'` y calcula la suma de `'CP'` para cada grupo.

# %%
result = df.groupby('PrimaryType')['CP'].sum().reset_index()
result
# Out:
#   PrimaryType      CP
# 0    Electric   500.0
# 1       Ghost   800.0
# 2       Grass   750.0
# 3      Normal     0.0
# 4       Water  1000.0

# %% [markdown]
# Después de la suma, agrega una columna que calcule la media de `'HP'` por cada `'Type'`, pero solo para aquellos Pokémon cuyo `'CP'` sea mayor que el promedio de `'CP'` de todo el DataFrame.

# %%
#sacamos la media de CP
mean = df['CP'].mean()
#filtramos para solo tener los CP mayor a la media
filt = df[df['CP'] > mean]
#Agrupamos por tipo en el df filtrado
grupo = filt.groupby('Type')
#sacamos el promedio de HP por los que son mayores a la media de CP
meanHP = grupo['HP'].mean()

#creamos nueva columna meanHP, mapeando los elementos de meanHP con los de type
df['meanHP'] = df['Type'].map(meanHP)
df
# Out:
#                SightingDate           SightingTimeUTC TrainerID PokémonName  \
# 0 2023-11-08 14:00:00+00:00 2023-11-08 14:00:00+00:00     TR123     Pikachu
# 1 2023-07-12 08:30:00+00:00 2023-07-12 08:30:00+00:00     TR456       Eevee
# 2 2023-02-23 13:15:00+00:00 2023-02-23 13:15:00+00:00     TR789    Magicarp
# 3 2023-04-30 10:45:00+00:00 2023-04-30 10:45:00+00:00     TR101      Gengar
# 4 2023-08-15 06:00:00+00:00                       NaT     TR102   Bulbasaur
#
#        CP  HP          Type        Weather         SightingTimeLocal  \
# 0   500.0  35      Electric          CLEAR 2023-11-08 14:00:00+00:00
# 1     NaN  55        Normal         CLOUDY 2023-07-12 08:30:00+00:00
# 2  1000.0  10         Water           RAIN 2023-02-23 13:15:00+00:00
# 3   800.0  45         Ghost  PARTLY_CLOUDY 2023-04-30 10:45:00+00:00
# 4   750.0  50  Grass/Poison          SUNNY 2023-08-15 06:00:00+00:00
#
#          TimeSinceSighting PrimaryType SecondaryType  HP_mean_cp  HP_mean_cp  \
# 0   5 days 04:48:43.904806    Electric          None         NaN         NaN
# 1 124 days 10:18:43.904806      Normal          None         NaN         NaN
# 2 263 days 05:33:43.904806       Water          None        10.0        10.0
# 3 197 days 08:03:43.904806       Ghost          None        45.0        45.0
# 4  90 days 12:48:43.904806       Grass        Poison         NaN         NaN
#
#    meanHP
# 0     NaN
# 1     NaN
# 2    10.0
# 3    45.0
# 4     NaN
