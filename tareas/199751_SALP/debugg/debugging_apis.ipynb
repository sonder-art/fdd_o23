# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/sonder-art/fdd_o23/blob/main/codigo/debugg/debugging_apis.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# Se entrega a mas tardar el martes 14 de Noviembre a las 11:55 pm. Vale 40 puntos de tarea.
# **Te recomiendo leer todo el ejercicio antes de empezar a hacer codigo, para que te des una idea de que formato y estructura necesitamos**

# %%
import pandas as pd
import requests

# %% [markdown]
# Objetivos del Ejercicio:
#
#     Realizar una solicitud a la API de Pokémon para obtener datos sobre un Pokémon específico.
#     Cargar y visualizar los datos en bruto para comprender su estructura.
#     Limpiar y organizar los datos para un análisis posterior.
#     Guardar los datos limpios en un archivo CSV.

# %% [markdown]
# El objetivo es crear un `DataFrame` (tidydata) de varios pokemones que ademas contengan metadata de sus moviemientos.
# Para ello deberas realizar request al `API` de pokemon, entender como vienen los datos y despues combinarlos con los `joins` correspondientes.

# %% [markdown]
# # API request

# %% [markdown]
# Crea codigo para acceder al API de pokemon y hacer requests. esta primera parte del codigo solo es para entender como es la estructura de los datos

# %% [markdown]
# Compelta el siguiente snippet para obter los datos del API de pokemon. La idea de estos primeros snippets es solo entender como funcionan los datos y como llegan. Para ello solo analizamos un pokemon y sus movimientos, mas adelante tenemos que repetirlo pero para varios pokemons.

# %% [markdown]
# ## Pokemon Data

# %% [markdown]
# Para  el tipo de pokemon debes obtener:
# 1. `pokemon_id`
# 2. `pokemon_name`
# 3. `type`(s) cada pokemon tiene a 1 o dos tipos (no mas). Tienes que guardar ambos
#
# Guarda los `moves` del pokemon pues los usaremos mas adelante. En especial el `name` y la `url` de cada movimiento para que podamos iterar despues

# %%
# Elige tu pokemon
pokemon_name = 'lucario'

# %%
# Solicitud para obtener datos de un Pokémon
pokemon_url = f'https://pokeapi.co/api/v2/pokemon/{pokemon_name}'
pokemon_response = requests.get(pokemon_url)
pokemon_data = pokemon_response.json()
moves  = pokemon_data['moves']
print(moves)
pokemon_obj = {'pokemon_id': pokemon_data['id'], 'pokemon_name': pokemon_data['name'], 'types':[t['type']['name'] for t in pokemon_data['types']]}
print(pokemon_obj)
# Out:
# [{'move': {'name': 'mega-punch', 'url': 'https://pokeapi.co/api/v2/move/5/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'sword-shield', 'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]}, {'move': {'name': 'ice-punch', 'url': 'https://pokeapi.co/api/v2/move/8/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'platinum', 'url': 'https://pokeapi.co/api/v2/version-group/9/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'heartgold-soulsilver', 'url': 'https://pokeapi.co/api/v2/version-group/10/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'black-2-white-2', 'url': 'https://pokeapi.co/api/v2/version-group/14/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'omega-ruby-alpha-sapphire', 'url': 'https://pokeapi.co/api/v2/version-group/16/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'ultra-sun-ultra-moon', 'url': 'https://pokeapi.co/api/v2/version-group/18/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'sword-shield', 'url': 'https://pokeapi.co/api/v2/version-group/20/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'scarlet-violet', 'url': 'https://pokeapi.co/api/v2/version-group/25/'}}]}, {'move': {'name': 'thunder-punch', 'url': 'https://pokeapi.co/api/v2/move/9/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'platinum', 'url': 'https://pokeapi.co/api/v2/version-group/9/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'heartgold-soulsilver', 'url': 'https://pokeapi.co/api/v2/version-group/10/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'black-2-white-2', 'url': 'https://pokeapi.co/api/v2/version-group/14/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'omega-ruby-alpha-sapphire', 'url': 'https://pokeapi.co/api/v2/version-group/16/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'ultra-sun-ultra-moon', 'url': 'https://pokeapi.co/api/v2/version-group/18/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'sword-shield', 'url': 'https://pokeapi.co/api/v2/version-group/20/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'scarlet-violet', 'url': 'https://pokeapi.co/api/v2/version-group/25/'}}]}, {'move': {'name': 'swords-dance', 'url': 'https://pokeapi.co/api/v2/move/14/'}, 'version_group_details': [{'level_learned_at': 33, 'move_learn_method': {'name': 'level-up', 'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'}, 'version_group': {'name': 'diamond-pearl', 'url': 'https://pokeapi.co/api/v2/version-group/8/'}},  ...
# {'pokemon_id': 448, 'pokemon_name': 'lucario', 'types': ['fighting', 'steel']}

# %% [markdown]
# ## Moves Data

# %% [markdown]
# Ahora para cada movimiento `move` del pokemon debes obtener los siguientes datos usando la `url`
# 1. `name`
# 2. `accuracy`
# 3. `type`
# 4. `power`
# 5. `pp`

# %%
# Solicitud para obtener datos de movimientos de un Pokémon
# Recuerda que esto es para explorar
structured_moves = []
for m in moves: # Modifica el codigo dependiendo de como hayas guardado los movimientos anteriormente
    # Codigo aqui
    moves_response = requests.get(m['move']['url'])
    moves_data = moves_response.json()
    structured_moves.append({
        "name":moves_data['name'], 
        "accuracy":moves_data['accuracy'], 
        "type":moves_data['type']['name'],
        "power":moves_data['power'],
        "pp":moves_data['pp']
    })
print(structured_moves)
# Out:
# [{'name': 'mega-punch', 'accuracy': 85, 'type': 'normal', 'power': 80, 'pp': 20}, {'name': 'ice-punch', 'accuracy': 100, 'type': 'ice', 'power': 75, 'pp': 15}, {'name': 'thunder-punch', 'accuracy': 100, 'type': 'electric', 'power': 75, 'pp': 15}, {'name': 'swords-dance', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 20}, {'name': 'mega-kick', 'accuracy': 75, 'type': 'normal', 'power': 120, 'pp': 5}, {'name': 'headbutt', 'accuracy': 100, 'type': 'normal', 'power': 70, 'pp': 15}, {'name': 'body-slam', 'accuracy': 100, 'type': 'normal', 'power': 85, 'pp': 15}, {'name': 'take-down', 'accuracy': 85, 'type': 'normal', 'power': 90, 'pp': 20}, {'name': 'roar', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 20}, {'name': 'hyper-beam', 'accuracy': 90, 'type': 'normal', 'power': 150, 'pp': 5}, {'name': 'low-kick', 'accuracy': 100, 'type': 'fighting', 'power': None, 'pp': 20}, {'name': 'counter', 'accuracy': 100, 'type': 'fighting', 'power': None, 'pp': 20}, {'name': 'strength', 'accuracy': 100, 'type': 'normal', 'power': 80, 'pp': 15}, {'name': 'earthquake', 'accuracy': 100, 'type': 'ground', 'power': 100, 'pp': 10}, {'name': 'dig', 'accuracy': 100, 'type': 'ground', 'power': 80, 'pp': 10}, {'name': 'toxic', 'accuracy': 90, 'type': 'poison', 'power': None, 'pp': 10}, {'name': 'psychic', 'accuracy': 100, 'type': 'psychic', 'power': 90, 'pp': 10}, {'name': 'agility', 'accuracy': None, 'type': 'psychic', 'power': None, 'pp': 30}, {'name': 'quick-attack', 'accuracy': 100, 'type': 'normal', 'power': 40, 'pp': 30}, {'name': 'screech', 'accuracy': 85, 'type': 'normal', 'power': None, 'pp': 40}, {'name': 'double-team', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 15}, {'name': 'focus-energy', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 30}, {'name': 'metronome', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 10}, {'name': 'swift', 'accuracy': None, 'type': 'normal', 'power': 60, 'pp': 20}, {'name': 'rest', 'accuracy': None, 'type': 'psychic', 'power': None, 'pp': 10}, {'name': 'rock-slide', 'accuracy': 90, 'type': 'rock', 'power': 75, 'pp': 10}, {'name': 'substitute', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 10}, {'name': 'snore', 'accuracy': 100, 'type': 'normal', 'power': 50, 'pp': 15}, {'name': 'reversal', 'accuracy': 100, 'type': 'fighting', 'power': None, 'pp': 15}, {'name': 'protect', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 10}, {'name': 'scary-face', 'accuracy': 100, 'type': 'normal', 'power': None, 'pp': 10}, {'name': 'mud-slap', 'accuracy': 100, 'type': 'ground', 'power': 20, 'pp': 10}, {'name': 'foresight', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 40}, {'name': 'detect', 'accuracy': None, 'type': 'fighting', 'power': None, 'pp': 5}, {'name': 'bone-rush', 'accuracy': 90, 'type': 'ground', 'power': 25, 'pp': 10}, {'name': 'endure', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 10}, {'name': 'swagger', 'accuracy': 85, 'type': 'normal', 'power': None, 'pp': 15}, {'name': 'fury-cutter', 'accuracy': 95, 'type': 'bug', 'power': 40, 'pp': 20}, {'name': 'attract', 'accuracy': 100, 'type': 'normal', 'power': None, 'pp': 15}, {'name': 'sleep-talk', 'accuracy': None, 'type': 'normal', 'power': None, 'pp': 10}, {'name': 'return', 'accuracy': 100, 'type': 'normal', 'power': None, 'pp': 20}, {'name': 'frustration', 'accuracy': 100, 'type': 'normal', 'power': None, 'pp': 20}, {'name': 'iron-tail', 'accuracy': 75, 'type': 'steel', 'power': 100, 'pp': 15}, {'name': 'metal-claw', 'accuracy': 95, 'type': 'steel', 'power': 50, 'pp': 35}, {'name': 'hidden-power', 'accuracy': 100, 'type': 'normal', 'power': 60, 'pp': 15}, {'name': 'rain-dance', 'accuracy': None, 'type': 'water', 'power': None, 'pp': 5}, {'name': 'sunny-day', 'accuracy': None, 'type': 'fire', 'power': None, 'pp': 5}, {'name': 'crunch', 'accuracy': 100, 'type': 'dark', 'power': 80, 'pp': 15}, {'name': 'extreme-speed', 'accuracy': 100, 'type': 'normal', 'power': 80, 'pp': 5}, {'na ...

# %% [markdown]
# # API Request para varios pokemons

# %% [markdown]
# Ahora que sabes como funciona el `API` realiza las peticiones de los siguientes pokemones respecto a sus caracteristicas
# y moviemientos, y guardalas en una lista, diciconario o tabla (lo que mas te acomode).

# %%
pokemons =['lucario', 'pikachu', 'gengar', 'charizard', 'blastoise', 'venusaur', 'dragonite', 'mew', 'mewtwo', 'garchomp']

# %%
# Solicitudes para obtener datos de un Pokémon
pokemon_raw_df = {'pokemon_id':[], 'pokemon_name':[],'type':[], 'move':[]}
structured_moves = []
for pokemon in pokemons:
    # Datos del Pokémon
    pokemon_url = f'https://pokeapi.co/api/v2/pokemon/{pokemon}'
    pokemon_response = requests.get(pokemon_url)
    pokemon_data = pokemon_response.json()
    moves  = pokemon_data['moves']
    pokemon_raw_df['pokemon_id'].append(pokemon_data['id'])
    pokemon_raw_df['pokemon_name'].append(pokemon_data['name'])
    pokemon_raw_df['type'].append([t['type']['name'] for t in pokemon_data['types']])
    pokemon_raw_df['move'].append([m['move']['name'] for m in pokemon_data['moves']])
    for m in moves:
        moves_response = requests.get(m['move']['url'])
        moves_data = moves_response.json()
        structured_moves.append({
            "name":moves_data['name'], 
            "accuracy":moves_data['accuracy'], 
            "type":moves_data['type']['name'],
            "power":moves_data['power'],
            "pp":moves_data['pp']
        })

# %% [markdown]
# # Evolucion a  Tabular

# %% [markdown]
# Ahora para cada request (`pokemon` y `movimiento`) convierte su informacion a datos tabulares. Toma en cuenta que vamos a realizar operaciones sobre esos DataFrames, por lo tanto tienes que elegir un formato adecuado.
# Para cada pokemon, y para cada movimiento debe existir un `DataFrame` o puedes guardarlos en uno solo, aunque es recomendable dejarlos por separado.

# %%
# Tu codigo aqui

pokemons_df = pd.DataFrame(pokemon_raw_df)
pokemons_df = pokemons_df.explode('type')
pokemons_df = pokemons_df.explode('move')
pokemons_df = pokemons_df.reset_index()
moves_df = pd.DataFrame.from_records(structured_moves)
moves_df = moves_df.drop_duplicates()



print(pokemons_df)
print(moves_df)
# Out:
#       index  pokemon_id pokemon_name      type             move
# 0         0         448      lucario  fighting       mega-punch
# 1         0         448      lucario  fighting        ice-punch
# 2         0         448      lucario  fighting    thunder-punch
# 3         0         448      lucario  fighting     swords-dance
# 4         0         448      lucario  fighting        mega-kick
# ...     ...         ...          ...       ...              ...
# 2082      9         445     garchomp    ground      liquidation
# 2083      9         445     garchomp    ground   breaking-swipe
# 2084      9         445     garchomp    ground       scale-shot
# 2085      9         445     garchomp    ground  scorching-sands
# 2086      9         445     garchomp    ground       tera-blast
#
# [2087 rows x 5 columns]
#                name  accuracy      type  power  pp
# 0        mega-punch      85.0    normal   80.0  20
# 1         ice-punch     100.0       ice   75.0  15
# 2     thunder-punch     100.0  electric   75.0  15
# 3      swords-dance       NaN    normal    NaN  20
# 4         mega-kick      75.0    normal  120.0   5
# ...             ...       ...       ...    ...  ..
# 1153         pounce     100.0       bug   50.0  20
# 1194        recover       NaN    normal    NaN  10
# 1268    miracle-eye       NaN   psychic    NaN  40
# 1307      psystrike     100.0   psychic  100.0  10
# 1324    sand-attack     100.0    ground    NaN  15
#
# [427 rows x 5 columns]

# %% [markdown]
# # Union de Informacion

# %% [markdown]
# 1. Obten el nombre y caracteristicas de todos lo movimientos que aparecen en por lo menos 3 pokemons de los de la lista (osea por lo menos 3 pokemons pueden realizar el movimiento), y guarda los datos de movimiento en un solo `DataFrame`

# %%
# Tu codigo aqui
full_pok_info = pokemons_df.join(moves_df.set_index('name'), on='move', how='inner',lsuffix='pok',rsuffix='mov')

moves_join_filter = full_pok_info.drop_duplicates(subset=['pokemon_name']).groupby(['move']).count()['pokemon_id']
filtered_moves = list(moves_join_filter[moves_join_filter >= 3].index)
moves_filtered_attributes = moves_df[moves_df['name'].isin(filtered_moves)]

# %% [markdown]
# 1.1 Salva los datos en un archivo csv

# %%
moves_filtered_attributes.to_csv('pokemon_moves_3.csv',index=False)

# %% [markdown]
# 2. Obten el nombre y caracteristicas todos los moviemientos que no se repiten en ningun otro pokemon, osea son movimientos unicos para un solo pokemon

# %%
# Tu codigo aqui
full_pok_info = pokemons_df.join(moves_df.set_index('name'), on='move', how='inner',lsuffix='pok',rsuffix='mov')

moves_join_filter = full_pok_info.drop_duplicates(subset=['pokemon_name']).groupby(['move']).count()['pokemon_id']
filtered_moves = list(moves_join_filter[moves_join_filter == 1].index)
moves_filtered_attributes = moves_df[moves_df['name'].isin(filtered_moves)]
moves_filtered_attributes
# Out:
# Empty DataFrame
# Columns: [name, accuracy, type, power, pp]
# Index: []

# %% [markdown]
# 2.2 Salvalos a un csv

# %%
moves_filtered_attributes.to_csv('unrepeated_moves.csv',index=False)

# %% [markdown]
# # Manejo de tipos

# %% [markdown]
# Para cada tipo de pokemon (fire, water, grass, etc) que aparecen en los datos. Obten una serie de dataframes que contengan a los pokemones que son de cada tipo. Y colocalos en un diccionarion donde la llave (`key`) es el tipo

# %%
# Tu codigo aqui
json_tipos = {}
all_types = list(pokemons_df.type.unique())
for type in all_types:
    json_tipos[type]=pokemons_df[pokemons_df['type']==type].groupby('pokemon_name').first().to_json()
json_tipos

# Esta es la estructura que debes crear al final
# Out:
# {'fighting': '{"index":{"lucario":0},"pokemon_id":{"lucario":448},"type":{"lucario":"fighting"},"move":{"lucario":"mega-punch"}}',
#  'steel': '{"index":{"lucario":0},"pokemon_id":{"lucario":448},"type":{"lucario":"steel"},"move":{"lucario":"mega-punch"}}',
#  'electric': '{"index":{"pikachu":1},"pokemon_id":{"pikachu":25},"type":{"pikachu":"electric"},"move":{"pikachu":"mega-punch"}}',
#  'ghost': '{"index":{"gengar":2},"pokemon_id":{"gengar":94},"type":{"gengar":"ghost"},"move":{"gengar":"mega-punch"}}',
#  'poison': '{"index":{"gengar":2,"venusaur":5},"pokemon_id":{"gengar":94,"venusaur":3},"type":{"gengar":"poison","venusaur":"poison"},"move":{"gengar":"mega-punch","venusaur":"swords-dance"}}',
#  'fire': '{"index":{"charizard":3},"pokemon_id":{"charizard":6},"type":{"charizard":"fire"},"move":{"charizard":"mega-punch"}}',
#  'flying': '{"index":{"charizard":3,"dragonite":6},"pokemon_id":{"charizard":6,"dragonite":149},"type":{"charizard":"flying","dragonite":"flying"},"move":{"charizard":"mega-punch","dragonite":"mega-punch"}}',
#  'water': '{"index":{"blastoise":4},"pokemon_id":{"blastoise":9},"type":{"blastoise":"water"},"move":{"blastoise":"mega-punch"}}',
#  'grass': '{"index":{"venusaur":5},"pokemon_id":{"venusaur":3},"type":{"venusaur":"grass"},"move":{"venusaur":"swords-dance"}}',
#  'dragon': '{"index":{"dragonite":6,"garchomp":9},"pokemon_id":{"dragonite":149,"garchomp":445},"type":{"dragonite":"dragon","garchomp":"dragon"},"move":{"dragonite":"mega-punch","garchomp":"swords-dance"}}',
#  'psychic': '{"index":{"mew":7,"mewtwo":8},"pokemon_id":{"mew":151,"mewtwo":150},"type":{"mew":"psychic","mewtwo":"psychic"},"move":{"mew":"pound","mewtwo":"mega-punch"}}',
#  'ground': '{"index":{"garchomp":9},"pokemon_id":{"garchomp":445},"type":{"garchomp":"ground"},"move":{"garchomp":"swords-dance"}}'}

# %% [markdown]
# Despues guara ese diccionario en un json llamado `tipos.json`

# %%
import json

with open('tipos.json', "w") as file:
    json.dump(json_tipos, file)

# %% [markdown]
# # Seleccion de Pokemones

# %% [markdown]
# Ahora crea un DataFrame que para cada pokemon unicamente contenga los movimientos que son de su tipo (osea si es tipo fuego y voldaor solo usa movimientos de tipo volador y fuego). Y crea una tabla donde tengan los siguientes datos en formato `tidydata`:
# 1. `pokemon_id`
# 2. `pokemon_name`
# 3. `type`(s) cada pokemon tiene a 1 o dos tipos (no mas). Tienes que guardar ambos
# 4. `name` (del movimiento)
# 5. `accuracy`
# 6. `type`
# 7. `power`
# 8. `pp`

# %%
# Tu codigo aqui
full_pok_info = pokemons_df.join(moves_df.set_index('name'), on='move', how='inner',lsuffix='pok',rsuffix='mov')
pokemons_move_types_equal = full_pok_info[full_pok_info['typepok']==full_pok_info['typemov']]
pokemons_move_types_equal
# Out:
#       index  pokemon_id pokemon_name   typepok             move  accuracy  \
# 222       1          25      pikachu  electric    thunder-punch     100.0
# 10        0         448      lucario  fighting         low-kick     100.0
# 11        0         448      lucario  fighting          counter     100.0
# 2010      9         445     garchomp    ground       earthquake     100.0
# 2011      9         445     garchomp    ground              dig     100.0
# ...     ...         ...          ...       ...              ...       ...
# 1715      7         151          mew   psychic  expanding-force     100.0
# 1900      8         150       mewtwo   psychic  expanding-force     100.0
# 1851      8         150       mewtwo   psychic      miracle-eye       NaN
# 1890      8         150       mewtwo   psychic        psystrike     100.0
# 1998      9         445     garchomp    ground      sand-attack     100.0
#
#        typemov  power  pp
# 222   electric   75.0  15
# 10    fighting    NaN  20
# 11    fighting    NaN  20
# 2010    ground  100.0  10
# 2011    ground   80.0  10
# ...        ...    ...  ..
# 1715   psychic   80.0  10
# 1900   psychic   80.0  10
# 1851   psychic    NaN  40
# 1890   psychic  100.0  10
# 1998    ground    NaN  15
#
# [270 rows x 9 columns]

# %% [markdown]
# Finalmente guarda los datos en `.parquet`

# %%
# Nombre del archivo: tabla_pokemon.parquet
pokemons_move_types_equal.to_parquet('table_pokemon.parquet',engine='fastparquet')
